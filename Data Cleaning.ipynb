# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Twitter has now become a useful way to build one's business as it helps in giving the brand a voice and a personality. The platform is also a quick, easy and inexpensive way to gain valuable insight from the desired audience. Identifying the sentiments about the product/brand can help the business take better actions.
#
# You have with you evaluated tweets about multiple brands. The evaluators(random audience) were asked if the tweet expressed positive, negative, or no emotion towards a product/brand and labelled accordingly.

# %% [markdown]
# # Business Intuation
#
# * Usecase:-
#  - Exploite the area of improvement
#  - Evaluate the Brand on Ground
#  - `Evaluate sentiment of tweet at real time`
# * Stakeholders:-
#  - Quqlity Manager
#  - CEO
#  - marketing head

# %% [markdown]
# # Dataset Description
# - Data is provided by Hackathon orgniser
# - This dataset contains around 7k tweet text with the sentiment label.
#
# The file train.csv has 3 columns
#
# tweet_id - Unique id for tweets. tweet - Tweet about the brand/product sentiment - 0: Negative, 1: Neutral, 2: Positive, 3: Can't Tell

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
from string import punctuation
import html
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics import f1_score,accuracy_score
from sklearn.linear_model import LogisticRegression
# Out:
# C:\Users\manda\Miniconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train = pd.read_csv("data/train.csv",encoding='utf-8').set_index('tweet_id')

# %%
pd.set_option('max_colwidth',150)
train.head(10)
# Out:
#                                                                                                                                                     tweet  \
# tweet_id
# 1701                                                            #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1851      Learning ab Google doodles! All doodles should be light, funny &amp; innovative, with exceptions for significant occasions. #GoogleDoodle #sxsw
# 2689                 one of the most in-your-face ex. of stealing the show in yrs RT @mention &quot;At #SXSW, Apple schools the mkt experts&quot;  {link}
# 4525                        This iPhone #SXSW app would b pretty awesome if it didn't crash every 10mins during extended browsing. #Fuckit #Illmakeitwork
# 3604                                                                        Line outside the Apple store in Austin waiting for the new iPad #SXSW  {link}
# 966                                   #technews One lone dude awaits iPad 2 at AppleÛªs SXSW store {link} #Tech_News #Apple #iPad_2 #SXSW #tablets #tech
# 1395                                                                 SXSW Tips, Prince, NPR Videos, Toy Shopping With Zuckerberg.\r\n{link}  #sxsw  #ipad
# 8182                              NU user RT @mention New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by #Mashable
# 8835                                                                                                       Free #SXSW sampler on iTunes {link} #FreeMusic
# 883                                                                       I think I might go all weekend without seeing the same iPad case twice... #sxsw
#
#           sentiment
# tweet_id
# 1701              1
# 1851              1
# 2689              2
# 4525              0
# 3604              1
# 966               1
# 1395              1
# 8182              1
# 8835              2
# 883               2

# %% [markdown]
# WittyWicky Inc. is a consulting firm that designs brand strategy for a lot of product startups. Their modus operandi is to gain the pulse of competing products and the associated sentiment from social media. Social media has profound impact in capturing the potential customers and thus there are a lot of consulting firms that operate in the digital strategy space. Whether it is to design a marketing campaign or look at the effect of marketing campaigns on user engagement or sentiment, it is a very valuable tool.
#
# Manual assessment of sentiment is very time consuming and automatic sentiment analysis would deliver a lot of value. As a team of data scientists consulting for WittyWicky Inc., you are now responsible for meeting their business outcomes.

# %%
train['sentiment'].value_counts()
# Out:
# 1    4311
# 2    2382
# 0     456
# 3     125
# Name: sentiment, dtype: int64

# %% [markdown]
# #### Function to remove patterns from data

# %%
def remov_pattern(pattern,text):
    text = re.sub(pattern,'',text)
    return text

# %% [markdown]
# #### Remove @mention
# #### Remove {link}
# #### Remove html tags
# As there are multiple html tags in the tweet column

# %%
pattern = "@[\w]*"
train['tweet'] = train['tweet'].apply(lambda x:remov_pattern(pattern,str(x)))

pattern = "{[\w }]*"
train['tweet'] = train['tweet'].apply(lambda x:remov_pattern(pattern,x))

#Eg: &quot;,&amp;
train['tweet'] = train['tweet'].apply(lambda x:html.unescape(x))

# %% [markdown]
# #### Removing bit.ly/ links

# %%
pattern = r"bit.ly/[\w]*"
train['tweet'] = train['tweet'].apply(lambda x:remov_pattern(pattern,x))

# %%
#pattern = "&[\w;]*"
#train['tweet'] = train['tweet'].apply(lambda x:remov_pattern(pattern,x))

# %% [markdown]
# ### Treating Slangs
#
# We scraped the website : "https://www.webopedia.com/quick_ref/textmessageabbreviations.asp"
# and obtained the table of slang words with their meanings

# %%
slangs_df = pd.read_csv("slangs_df.csv")
slangs_df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
slangs_df.head(30)
# Out:
#     Slangs                     Full_Forms
# 0       4U                        For you
# 1   @TEOTD          At the end of the day
# 2      121                    One-to-one
# 3      143                     I love you
# 4     1432                 I love you too
# 5   14AA41   One for all, and all for one
# 6      182                     I hate you
# 7      10X                         Thanks
# 8      10Q                      Thank you
# 9       2B                          To be
# 10     2EZ                       Too easy
# 11   2G2BT            Too good to be true
# 12    2M2H            Too much too handle
# 13     2MI           Too much information
# 14    2MOR                       Tomorrow
# 15   2MORO                       Tomorrow
# 16    2M2H             Too much to handle
# 17     2N8                        Tonight
# 18     4AO                For adults only
# 19    4COL            For crying out loud
# 20    4EAE              Forever and ever
# 21    4EVA                        Forever
# 22     4NR                     Foreigner
# 23   4SALE                       For sale
# 24      ^5                      High-five
# 25      6Y                           Sexy
# 26      7K                           Sick
# 27      A3    Anytime, anywhere, anyplace
# 28      AA           Alcoholics Anonymous
# 29      AA                       As above

# %%
def df_to_dict(df,df_dict):
    for index,row in df.iterrows():
        df_dict[row['Slangs']] = row['Full_Forms']
    return df_dict

slangs_dict = {}
slangs_dict = df_to_dict(slangs_df,slangs_dict)
slangs_dict['PC'] = "Personal Computer"

# %%
def treat_slangs(row,slang_dict):
    words = row.split()
    treated_row = []
    reformed = []
    for word in words:
        if word.upper() in slang_dict.keys():
            new_word = word.replace(word,slang_dict[word.upper()])
            treated_row.append(new_word)
        else:
            treated_row.append(word)
    reformed = " ".join(treated_row)
    return reformed
train['tweet'] = train['tweet'].apply(lambda x:treat_slangs(x,slangs_dict))

# %%
#IGNORE....................................


chat_words_str = """AFAIK=As Far As I Know
AFK=Away From Keyboard
ASAP=As Soon As Possible
ATK=At The Keyboard
ATM=At The Moment
A3=Anytime, Anywhere, Anyplace
BAK=Back At Keyboard
BBL=Be Back Later
BBS=Be Back Soon
BFN=Bye For Now
B4N=Bye For Now
BRB=Be Right Back
BRT=Be Right There
BTW=By The Way
B4=Before
B4N=Bye For Now
CU=See You
CUL8R=See You Later
CYA=See You
FAQ=Frequently Asked Questions
FC=Fingers Crossed
FWIW=For What It's Worth
FYI=For Your Information
GAL=Get A Life
GG=Good Game
GN=Good Night
GMTA=Great Minds Think Alike
GR8=Great!
G9=Genius
IC=I See
ICQ=I Seek you 
ILU=I Love You
IMHO=In My Honest/Humble Opinion
IMO=In My Opinion
IOW=In Other Words
IRL=In Real Life
KISS=Keep It Simple, Stupid
LDR=Long Distance Relationship
LMAO=Laugh My Ass Off
LOL=Laughing Out Loud
LTNS=Long Time No See
L8R=Later
MTE=My Thoughts Exactly
M8=Mate
NRN=No Reply Necessary
OIC=Oh I See
PITA=Pain In The A..
PRT=Party
PRW=Parents Are Watching
ROFL=Rolling On The Floor Laughing
ROFLOL=Rolling On The Floor Laughing Out Loud
ROTFLMAO=Rolling On The Floor Laughing My Ass Off
SK8=Skate
STATS=Your sex and age
ASL=Age, Sex, Location
THX=Thank You
TTFN=Ta-Ta For Now!
TTYL=Talk To You Later
U=You
U2=You Too
U4E=Yours For Ever
WB=Welcome Back
WTF=What The Fuck
WTG=Way To Go!
WUF=Where Are You From?
W8=Wait
7K=Sick
YRS=Years
MKT=Market"""

chat_words_str = chat_words_str.replace("\n",":")
chat_words_split = chat_words_str.split(":")
slangs = list(chat_words_split)

# %%
#IGNORE............................
slangs_words = []
full_forms = []
for slang in slangs:
    new_slang = slang.split("=")
    slangs_words.append(new_slang[0])
    full_forms.append(new_slang[1])

# %%
#Ignore.............................
slang_words_small = {}
for i in range(len(slangs_words)):
    slang_words_small[slangs_words[i]] = full_forms[i]

# %%
#from gingerit.gingerit import GingerIt

# %%
#parser = GingerIt()
#text = "They're giving away iPad 2's, x boxes and books at @mention #sxsw #techenvy"
#tweet = parser.parse(text)
#print(tweet)
# Out:
# {'text': "They're giving away iPad 2's, x boxes and books at @mention #sxsw #techenvy", 'result': "They're giving away iPad 2's, x boxes and books at @mention #sxsw #techenvy", 'corrections': []}

# %%
#a = train.iloc[:20,:]

# %%
#parser = GingerIt()
#b = a['tweet'].apply(lambda x:parser.parse(x))

# %%
#b.values
# Out:
# array([{'text': '#sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller', 'result': '#sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller', 'corrections': []},
#        {'text': 'Learning ab Google doodles! All doodles should be light, funny & innovative, with exceptions for significant occasions. #GoogleDoodle #sxsw', 'result': 'Learning ab Google doodles! All doodles should be light, funny & innovative, with exceptions for significant occasions. #GoogleDoodle #sxsw', 'corrections': []},
#        {'text': 'one of the most in-your-face ex. of stealing the show in yrs RT  "At #SXSW, Apple schools the mkt experts"  ', 'result': 'One of the most in-your-face ex. Of stealing the show in yrs RT  "At #SXSW, Apple schools the market experts"  ', 'corrections': [{'start': 94, 'text': 'mkt', 'correct': 'market', 'definition': 'the world of commercial activity where goods and services are bought and sold'}, {'start': 33, 'text': 'of', 'correct': 'Of', 'definition': None}, {'start': 0, 'text': 'one', 'correct': 'One', 'definition': None}]},
#        {'text': "This iPhone #SXSW app would b pretty awesome if it didn't crash every 10mins during extended browsing. #Fuckit #Illmakeitwork", 'result': "This iPhone #SXSW app would be pretty awesome if it didn't crash every 10mins during extended browsing. #Fuckit #Illmakeitwork", 'corrections': [{'start': 28, 'text': 'b', 'correct': 'be', 'definition': 'have the quality of being; (copula, used with an adjective or a predicate noun)'}]},
#        {'text': 'Line outside the Apple store in Austin waiting for the new iPad #SXSW  ', 'result': 'The line outside the Apple store in Austin waiting for the new iPad #SXSW  ', 'corrections': [{'start': 0, 'text': 'Line', 'correct': 'The line', 'definition': None}]},
#        {'text': '#technews One lone dude awaits iPad 2 at Apple\x89Ûªs SXSW store #Tech_News #Apple #iPad_2 #SXSW #tablets #tech', 'result': '#technews One lone dude awaits iPad 2 at Apple\x89Ûªs SXSW store #Tech_News #Apple #iPad_2 #SXSW #tablets #tech', 'corrections': []},
#        {'text': 'SXSW Tips, Prince, NPR Videos, Toy Shopping With Zuckerberg.\r\n#sxsw  #ipad', 'result': 'SXSW Tips, Prince, NPR Videos, Toy Shopping With Zuckerberg.\r\n#sxsw  #ipad', 'corrections': []},
#        {'text': 'NU user RT  New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by #Mashable', 'result': 'NU user RT  New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by #Mashable', 'corrections': []},
#        {'text': 'Free #SXSW sampler on iTunes #FreeMusic', 'result': 'Free #SXSW sampler on iTunes #FreeMusic', 'corrections': []},
#        {'text': 'I think I might go all weekend without seeing the same iPad case twice... #sxsw', 'result': 'I think I might go all weekend without seeing the same iPad case twice... #sxsw', 'corrections': []},
#        {'text': 'RT  Official #SXSW App \x89Û÷SXSW GO\x89Ûª bit.ly/hmiiGa #android #iphone #ipad', 'result': 'RT  Official #SXSW App \x89Û÷SXSW GO\x89Ûª bit. Li/hmiiGa #android #iphone #ipad', 'corrections': [{'start': 41, 'text': 'ly', 'correct': 'Li', 'definition': 'a soft silver-white univalent element of the alkali metal group; the lightest metal known; occurs in several minerals'}, {'start': 40, 'text': '.', 'correct': '. ', 'definition': 'Accept space'}]},
#        {'text': "It's official! I'm buying an iPad. #SXSW #elevate", 'result': "It's official! I'm buying an iPad. #SXSW #elevate", 'corrections': []},
#        {'text': "They're giving away iPad 2's, x boxes and books at  #sxsw #techenvy", 'result': "They're giving away iPad 2's, x boxes and books at  #sxsw #techenvy", 'corrections': []},
#        {'text': "RT  We're officially at #SXSW! Come by the  Grill, mention us w/ #zazzlsxsw and you\x89Ûªll get to make your own iPhone case!", 'result': "RT  We're officially at #SXSW! Come by the  Grill, mention us w/ #zazzlsxsw and you\x89Ûªll get to make your own iPhone case!", 'corrections': []},
#        {'text': '#Companies to watch, from the #SXSW trade show floor #apps #features #hardware #ipad #iphone', 'result': '#Companies to watch, from the #SXSW trade show floor #apps #features #hardware #ipad #iphone', 'corrections': []},
#        {'text': 'RT  Google Marissa Mayer, future of location: augmented reality, contextual discovery, make smartphones smarter. #sxsw', 'result': 'RT  Google, Marissa Mayer, future of location: augmented reality, contextual discovery, makes smartphones smarter. #sxsw', 'corrections': [{'start': 87, 'text': 'make', 'correct': 'makes', 'definition': None}, {'start': 4, 'text': 'Google Marissa', 'correct': 'Google, Marissa', 'definition': 'Accept comma addition'}]},
#        {'text': 'DL the #Calyp App to get into #Calyp Casa at #SXSW the free mobile app is available in iTunes App Store & Android Market. See u there!', 'result': 'DL the #Calyp App to get into #Calyp CASA at #SXSW the free mobile app is available in iTunes App Store & Android Market. See you there!', 'corrections': [{'start': 126, 'text': 'u', 'correct': 'you', 'definition': 'second person pronoun; the person addressed'}, {'start': 37, 'text': 'Casa', 'correct': 'CASA', 'definition': None}]},
#        {'text': 'Well yeah.  Music > iPhone nerds RT  my god, cute girls everywhere...I love when interactive ends and music begins #sxsw', 'result': 'Well, yeah.  Music > iPhone nerds RT  my god, cute girls everywhere... I love when interactive ends and the music begins #sxsw', 'corrections': [{'start': 102, 'text': 'music', 'correct': 'the music', 'definition': None}, {'start': 66, 'text': '...', 'correct': '... ', 'definition': 'Accept space'}, {'start': 0, 'text': 'Well yeah', 'correct': 'Well, yeah', 'definition': 'Accept comma addition'}]},
#        {'text': 'Apple Opens Pop Up Store at SXSW #apple #iPad2 #technology #iTunes #SXSW', 'result': 'Apple Opens Pop Up Store at SXSW #apple #iPad2 #technology #iTunes #SXSW', 'corrections': []},
#        {'text': " atleast you are at #sxsw. I'm not there AND I have no Ipad. #doubleloser", 'result': " At least you are at #sxsw. I'm not there AND I have no iPad. #doubleloser", 'corrections': [{'start': 55, 'text': 'Ipad', 'correct': 'iPad', 'definition': None}, {'start': 1, 'text': 'atleast', 'correct': 'At least', 'definition': None}]}],
#       dtype=object)

# %% [markdown]
# #### Treating Apostrophes

# %%
apostrophes = {
"aren't" : "are not",
"can't" : "cannot",
"couldn't" : "could not",
"didn't" : "did not",
"doesn't" : "does not",
"don't" : "do not",
"hadn't" : "had not",
"hasn't" : "has not",
"haven't" : "have not",
"he'd" : "he would",
"he'll" : "he will",
"he's" : "he is",
"i'd" : "I would",
"i'd" : "I had",
"i'll" : "I will",
"i'm" : "I am",
"isn't" : "is not",
"it's" : "it is",
"it'll":"it will",
"i've" : "I have",
"let's" : "let us",
"mightn't" : "might not",
"mustn't" : "must not",
"shan't" : "shall not",
"she'd" : "she would",
"she'll" : "she will",
"she's" : "she is",
"shouldn't" : "should not",
"that's" : "that is",
"there's" : "there is",
"they'd" : "they would",
"they'll" : "they will",
"they're" : "they are",
"they've" : "they have",
"we'd" : "we would",
"we're" : "we are",
"weren't" : "were not",
"we've" : "we have",
"what'll" : "what will",
"what're" : "what are",
"what's" : "what is",
"what've" : "what have",
"where's" : "where is",
"who'd" : "who would",
"who'll" : "who will",
"who're" : "who are",
"who's" : "who is",
"who've" : "who have",
"won't" : "will not",
"wouldn't" : "would not",
"you'd" : "you would",
"you'll" : "you will",
"you're" : "you are",
"you've" : "you have",
"'re": " are",
"wasn't": "was not",
"we'll":" will",
"didn't": "did not",
"'s" : " ",
"'m" : " am"
}

# %%
def apostrophe_correction(row):
    words = row.split()
    cleaned_row = []
    for word in words:
        for apostrophe in apostrophes:
            if apostrophe in word:
                word = word.replace(apostrophe, apostrophes[apostrophe]) 
        cleaned_row.append(word)
    reformed = " ".join(cleaned_row)
    return reformed
train['tweet']=train.tweet.apply(apostrophe_correction)

# %%
train.head(10)
# Out:
#                                                                                                                                                 tweet  \
# tweet_id
# 1701                                                        #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1851      Learning ab Google doodles! All doodles should be light, funny & innovative, with exceptions for significant occasions. #GoogleDoodle #sxsw
# 2689                                   one of the most in-your-face ex. of stealing the show in Years RT "At #SXSW, Apple schools the Market experts"
# 4525                   This iPhone #SXSW app would b pretty awesome if it did not crash every 10mins during extended browsing. #Fuckit #Illmakeitwork
# 3604                                                                            Line outside the Apple store in Austin waiting for the new iPad #SXSW
# 966                                      #technews One lone dude awaits iPad 2 at AppleÛªs SXSW store #Tech_News #Apple #iPad_2 #SXSW #tablets #tech
# 1395                                                                         SXSW Tips, Prince, NPR Videos, Toy Shopping With Zuckerberg. #sxsw #ipad
# 8182                                   NU user RT New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by #Mashable
# 8835                                                                                                          Free #SXSW sampler on iTunes #FreeMusic
# 883                                                                   I think I might go all weekend without seeing the same iPad case twice... #sxsw
#
#           sentiment
# tweet_id
# 1701              1
# 1851              1
# 2689              2
# 4525              0
# 3604              1
# 966               1
# 1395              1
# 8182              1
# 8835              2
# 883               2

# %%
tb_polarity = []
tb_subjectivity = []
for row in train["tweet"]:
    temp = TextBlob(row)
    tb_polarity.append(temp.sentiment[0])
    tb_subjectivity.append(temp.sentiment[1])
train["tb_polarity"] = tb_polarity
train["tb_subjectivity"] = tb_subjectivity

# %%
#IGNORE..................

analyser = SentimentIntensityAnalyzer()
vs_polarity = []
for row in train["tweet"]:
    temp = analyser.polarity_scores(row)['compound']
    vs_polarity.append(temp)
train["vs_polarity"] = vs_polarity

# %%
text = "one of the example of stealing the show in Years RT At #SXSW, Apple schools the Market experts"
analyser = SentimentIntensityAnalyzer()
sent = analyser.polarity_scores(text)

# %%
sent
# Out:
# {'neg': 0.179, 'neu': 0.821, 'pos': 0.0, 'compound': -0.5719}

# %%
train.head()
# Out:
#                                                                                                                                                 tweet  \
# tweet_id
# 1701                                                        #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1851      Learning ab Google doodles! All doodles should be light, funny & innovative, with exceptions for significant occasions. #GoogleDoodle #sxsw
# 2689                                   one of the most in-your-face ex. of stealing the show in Years RT "At #SXSW, Apple schools the Market experts"
# 4525          This iPhone #SXSW Application would Be pretty awesome if it did not crash every 10mins during extended browsing. #Fuckit #Illmakeitwork
# 3604                                                                            Line outside the Apple store in Austin waiting for the new iPad #SXSW
#
#           sentiment  tb_polarity  tb_subjectivity  vs_polarity
# tweet_id
# 1701              1     0.150000         0.650000       0.0000
# 1851              1     0.381250         0.893750       0.7840
# 2689              2     0.500000         0.500000      -0.5719
# 4525              0     0.625000         1.000000       0.8611
# 3604              1     0.068182         0.252273       0.0000

# %% [markdown]
# #### Remove Special characters
# Eg : Ã‰ -> É â€œ -> " â€ -> " Ã‡ -> Ç Ãƒ -> Ã Ã©, 'é Ã -> À Ãº -> ú â€¢ -> - Ã˜ -> Ø Ãµ -> õ Ã­ -> í Ã¢ -> â Ã£ -> ã Ãª -> ê Ã¡ -> á Ã© -> é Ã³ -> ó â€“ -> – Ã§ -> ç Âª -> ª Âº -> º Ã -> à

# %%
pattern = "[^a-zA-Z\s#]" 
train['tweet'] = train['tweet'].apply(lambda x:remov_pattern(pattern,x))

# %%
train.head(25)
# Out:
#                                                                                                                                                           tweet  \
# tweet_id
# 1701                                                                  #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1851                     Learning ab Google doodles All doodles should be light funny  innovative with exceptions for significant occasions #GoogleDoodle #sxsw
# 2689                                                        one of the most inyourface ex of stealing the show in yrs RT At #SXSW Apple schools the mkt experts
# 4525                       This iPhone #SXSW Application would Be pretty awesome if it did not crash every mins during extended browsing #Fuckit #Illmakeitwork
# 3604                                                                                      Line outside the Apple store in Austin waiting for the new iPad #SXSW
# 966                                                       #technews One lone dude awaits iPad  at Apples SXSW store #TechNews #Apple #iPad #SXSW #tablets #tech
# 1395                                                                                       SXSW Tips Prince NPR Videos Toy Shopping With Zuckerberg #sxsw #ipad
# 8182                                     NU user RT New #UberSocial for #iPhone now in the Application Store includes UberGuide to #SXSW sponsored by #Mashable
# 8835                                                                                                                    Free #SXSW sampler on iTunes #FreeMusic
# 883                                                                                I think I might go all weekend without seeing the same iPad case twice #sxsw
# 6398                                                                                   RT Official #SXSW Application SXSW GO bitlyhmiiGa #android #iphone #ipad
# 2369                                                                                                            It  official I am buying an iPad #SXSW #elevate
# 3944                                                                                           They are giving away iPad   x boxes and books at #sxsw #techenvy
# 6909                                      RT We are officially at #SXSW Come by the Grill mention us With #zazzlsxsw and youll get to make your own iPhone case
# 7917                                                                #Companies to watch from the #SXSW trade show floor #apps #features #hardware #ipad #iphone
# 5849                                           RT Google Marissa Mayer future of location augmented reality contextual discovery make smartphones smarter #sxsw
# 1955      Download the #Calyp Application to get into #Calyp Casa at #SXSW the free mobile Application is available in iTunes Application Store  Android Mar...
# 1472                                           Well yeah Music  iPhone nerds RT my god cute girls everywhereI love when interactive ends and music begins #sxsw
# 4730                                                                                    Apple Opens Pop Up Store at SXSW #apple #iPad #technology #iTunes #SXSW
# 2166                                                                                    atleast you are at #sxsw I am not there AND I have no Ipad #doubleloser
# 3497                                                                                                                 Cue the choir music #SXSW Apple Store SXSW
# 165                                      Anyone at #sxsw want an iPad  I am in line and will pick one up for someone willing to pay me  for me to grab  for you
# 1352                                                                              Google to Launch Major New Social Network Called Circles Possibly Today #sxsw
# 6431                                                                                    RT PS and Google throw a btchin party Shout out to The Spazmatics #sxsw
# 634                                                 I have a G iPhone After  hrs tweeting at #RISEAustin it was dead I need to upgrade Plugin stations at #SXSW
#
#           sentiment
# tweet_id
# 1701              1
# 1851              1
# 2689              2
# 4525              0
# 3604              1
# 966               1
# 1395              1
# 8182              1
# 8835              2
# 883               2
# 6398              3
# 2369              2
# 3944              2
# 6909              1
# 7917              1
# 5849              1
# 1955              1
# 1472              2
# 4730              1
# 2166              1
# 3497              1
# 165               1
# 1352              2
# 6431              2
# 634               0

# %% [markdown]
# #### 1. Add hashtags to a seperate column
# #### 2. Remove hashtags

# %%
train['hashtags'] = train['tweet'].apply(lambda x:','.join(re.findall("#[\w]*",x)))
train['hashtags'] = train['hashtags'].apply(lambda x:re.sub("[#]*","",x))
train['hashtags'] = train['hashtags'].apply(lambda x:x.lower())

# %%
train.head()
# Out:
#                                                                                                                                            tweet  \
# tweet_id
# 1701                                                   #sxswnui #sxsw #apple defining language of touch with different dialects becoming smaller
# 1851      Learning ab Google doodles All doodles should be light funny  innovative with exceptions for significant occasions #GoogleDoodle #sxsw
# 2689                                         one of the most inyourface ex of stealing the show in yrs RT At #SXSW Apple schools the mkt experts
# 4525                 This iPhone #SXSW app would b pretty awesome if it did not crash every mins during extended browsing #Fuckit #Illmakeitwork
# 3604                                                                       Line outside the Apple store in Austin waiting for the new iPad #SXSW
#
#           sentiment                   hashtags
# tweet_id
# 1701              1         sxswnui,sxsw,apple
# 1851              1          googledoodle,sxsw
# 2689              2                       sxsw
# 4525              0  sxsw,fuckit,illmakeitwork
# 3604              1                       sxsw

# %%
train['hashtags'] = train['hashtags'].apply(lambda x: re.sub(","," ",x))

# %%
train['tweet'] = train['tweet'].apply(lambda x:re.sub("#[\w]*",'',x))

# %%
train['tweet'] = train['tweet'].str.lower()

# %% [markdown]
# #### Removing RT

# %%
train['tweet'] = train['tweet'].apply(lambda x:re.sub(r"\brt","",x,flags=re.IGNORECASE))

# %%
train.head(10)
# Out:
#                                                                                            tweet  \
# tweet_id
# 1701                                  defining language touch different dialect becoming smaller
# 1851      learning ab google doodle doodle light funny innovative exception significant occasion
# 2689                               one inyourface ex stealing show yr rt apple school mkt expert
# 4525                   iphone application would pretty awesome crash every min extended browsing
# 3604                                            line outside apple store austin waiting new ipad
# 966                                                   one lone dude awaits ipad apple sxsw store
# 1395                                           sxsw tip prince npr video toy shopping zuckerberg
# 8182                               nu user rt new application store includes uberguide sponsored
# 8835                                                                         free sampler itunes
# 883                                        think might go weekend without seeing ipad case twice
#
#           sentiment  length                                        hashtags
# tweet_id
# 1701              1      89                              sxswnui sxsw apple
# 1851              1     143                               googledoodle sxsw
# 2689              2     132                                            sxsw
# 4525              0     125                       sxsw fuckit illmakeitwork
# 3604              1      77                                            sxsw
# 966               1     115  technews technews apple ipad sxsw tablets tech
# 1395              1      82                                       sxsw ipad
# 8182              1     119                 ubersocial iphone sxsw mashable
# 8835              2      46                                  sxsw freemusic
# 883               2      79                                            sxsw

# %%
#text = "_¼ÛÄ___ü ___¡ _____«_µ... &gt;&gt; @mention Google to Launch Major New Social Network Called Circles, Possibly Today sxs"
#text_c = text.decode("utf8").encode('ascii','ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-f304b1008ae5> in <module>
#       1 text = "_¼ÛÄ___ü ___¡ _____«_µ... &gt;&gt; @mention Google to Launch Major New Social Network Called Circles, Possibly Today sxs"
# ----> 2 text_c = text.decode("utf8").encode('ascii','ignore')
#
# AttributeError: 'str' object has no attribute 'decode'

# %% [markdown]
# #### Stopwords Removal

# %%
sxsw_patterns = []
def find_pattern(df,pattern):
    r = re.findall(pattern,df)
    for i in r:
        if i not in sxsw_patterns:
            sxsw_patterns.append(i)
pattern = "sxsw[\w]*"
train['tweet'].apply(lambda x:find_pattern(x,pattern))
# Out:
# tweet_id
# 1701    None
# 1851    None
# 2689    None
# 4525    None
# 3604    None
#         ...
# 3343    None
# 5334    None
# 5378    None
# 2173    None
# 3162    None
# Name: tweet, Length: 7274, dtype: object

# %%
stop_words = list(set(stopwords.words('english')))+list(punctuation)
train['tweet'] = train['tweet'].apply(lambda x:word_tokenize(x))
train['tweet'] = train['tweet'].apply(lambda row:[word for word in row if word not in stop_words])

# %%
train.head(20)
# Out:
#                                                                                                                                   tweet  \
# tweet_id
# 1701                                                                [defining, language, touch, different, dialects, becoming, smaller]
# 1851                             [learning, ab, google, doodles, doodles, light, funny, innovative, exceptions, significant, occasions]
# 2689                                                       [one, inyourface, ex, stealing, show, yrs, rt, apple, schools, mkt, experts]
# 4525                                              [iphone, application, would, pretty, awesome, crash, every, mins, extended, browsing]
# 3604                                                                          [line, outside, apple, store, austin, waiting, new, ipad]
# 966                                                                                [one, lone, dude, awaits, ipad, apples, sxsw, store]
# 1395                                                                       [sxsw, tips, prince, npr, videos, toy, shopping, zuckerberg]
# 8182                                                            [nu, user, rt, new, application, store, includes, uberguide, sponsored]
# 8835                                                                                                            [free, sampler, itunes]
# 883                                                                     [think, might, go, weekend, without, seeing, ipad, case, twice]
# 6398                                                                                 [rt, official, application, sxsw, go, bitlyhmiiga]
# 2369                                                                                                           [official, buying, ipad]
# 3944                                                                                              [giving, away, ipad, x, boxes, books]
# 6909                                                         [rt, officially, come, grill, mention, us, youll, get, make, iphone, case]
# 7917                                                                                                        [watch, trade, show, floor]
# 5849              [rt, google, marissa, mayer, future, location, augmented, reality, contextual, discovery, make, smartphones, smarter]
# 1955      [download, application, get, casa, free, mobile, application, available, itunes, application, store, android, market, see, u]
# 1472                      [well, yeah, music, iphone, nerds, rt, god, cute, girls, everywherei, love, interactive, ends, music, begins]
# 4730                                                                                                   [apple, opens, pop, store, sxsw]
# 2166                                                                                                                    [atleast, ipad]
#
#           sentiment  length                                           hashtags
# tweet_id
# 1701              1      89                                 sxswnui sxsw apple
# 1851              1     143                                  googledoodle sxsw
# 2689              2     132                                               sxsw
# 4525              0     125                          sxsw fuckit illmakeitwork
# 3604              1      77                                               sxsw
# 966               1     115     technews technews apple ipad sxsw tablets tech
# 1395              1      82                                          sxsw ipad
# 8182              1     119                    ubersocial iphone sxsw mashable
# 8835              2      46                                     sxsw freemusic
# 883               2      79                                               sxsw
# 6398              3      81                           sxsw android iphone ipad
# 2369              2      49                                       sxsw elevate
# 3944              2      75                                      sxsw techenvy
# 6909              1     138                                     sxsw zazzlsxsw
# 7917              1      99  companies sxsw apps features hardware ipad iphone
# 5849              1     126                                               sxsw
# 1955              1     138                                   calyp calyp sxsw
# 1472              2     131                                               sxsw
# 4730              1      92                  apple ipad technology itunes sxsw
# 2166              1      81                                   sxsw doubleloser

# %% [markdown]
# ### Lemmatization

# %%
lemma = WordNetLemmatizer()
train['tweet'] = train['tweet'].apply(lambda x:[lemma.lemmatize(i) for i in x])

# %%
train.head(10)
# Out:
#                                                                                                    tweet  \
# tweet_id
# 1701                                  [defining, language, touch, different, dialect, becoming, smaller]
# 1851      [learning, google, doodle, doodle, light, funny, innovative, exception, significant, occasion]
# 2689                      [one, inyourface, ex, stealing, show, year, rt, apple, school, market, expert]
# 4525                [iphone, application, would, pretty, awesome, crash, every, min, extended, browsing]
# 3604                                           [line, outside, apple, store, austin, waiting, new, ipad]
# 966                                                  [one, lone, dude, awaits, ipad, apple, sxsw, store]
# 1395                                          [sxsw, tip, prince, npr, video, toy, shopping, zuckerberg]
# 8182                             [nu, user, rt, new, application, store, includes, uberguide, sponsored]
# 8835                                                                             [free, sampler, itunes]
# 883                                      [think, might, go, weekend, without, seeing, ipad, case, twice]
#
#           sentiment  tb_polarity  tb_subjectivity  \
# tweet_id
# 1701              1     0.150000         0.650000
# 1851              1     0.381250         0.893750
# 2689              2     0.500000         0.500000
# 4525              0     0.625000         1.000000
# 3604              1     0.068182         0.252273
# 966               1     0.000000         0.000000
# 1395              1     0.000000         0.000000
# 8182              1     0.136364         0.454545
# 8835              2     0.400000         0.800000
# 883               2     0.000000         0.125000
#
#                                                 hashtags
# tweet_id
# 1701                                  sxswnui sxsw apple
# 1851                                   googledoodle sxsw
# 2689                                                sxsw
# 4525                           sxsw fuckit illmakeitwork
# 3604                                                sxsw
# 966       technews technews apple ipad sxsw tablets tech
# 1395                                           sxsw ipad
# 8182                     ubersocial iphone sxsw mashable
# 8835                                      sxsw freemusic
# 883                                                 sxsw

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()
train['tweet'] = train['tweet'].apply(lambda x:[stemmer.stem(i) for i in x])

# %%
train['tweet'] = train['tweet'].apply(lambda x:' '.join(x))

# %%
train.head(10)
# Out:
#                                                                                            tweet  \
# tweet_id
# 1701                                  defining language touch different dialect becoming smaller
# 1851      learning ab google doodle doodle light funny innovative exception significant occasion
# 2689                          one inyourface ex stealing show year rt apple school market expert
# 4525                   iphone application would pretty awesome crash every min extended browsing
# 3604                                            line outside apple store austin waiting new ipad
# 966                                                   one lone dude awaits ipad apple sxsw store
# 1395                                           sxsw tip prince npr video toy shopping zuckerberg
# 8182                               nu user rt new application store includes uberguide sponsored
# 8835                                                                         free sampler itunes
# 883                                        think might go weekend without seeing ipad case twice
#
#           sentiment  tb_polarity  tb_subjectivity  \
# tweet_id
# 1701              1     0.150000         0.650000
# 1851              1     0.381250         0.893750
# 2689              2     0.500000         0.500000
# 4525              0     0.625000         1.000000
# 3604              1     0.068182         0.252273
# 966               1     0.000000         0.000000
# 1395              1     0.000000         0.000000
# 8182              1     0.136364         0.454545
# 8835              2     0.400000         0.800000
# 883               2     0.000000         0.125000
#
#                                                 hashtags
# tweet_id
# 1701                                  sxswnui sxsw apple
# 1851                                   googledoodle sxsw
# 2689                                                sxsw
# 4525                           sxsw fuckit illmakeitwork
# 3604                                                sxsw
# 966       technews technews apple ipad sxsw tablets tech
# 1395                                           sxsw ipad
# 8182                     ubersocial iphone sxsw mashable
# 8835                                      sxsw freemusic
# 883                                                 sxsw

# %% [markdown]
# #### Count Vectorizer

# %%
cv = CountVectorizer()
text = train['tweet']
vector = cv.fit_transform(text)
X = vector.toarray()

# %% [markdown]
# #### Tfidf Vectorizer

# %%
text = train['tweet']
tfidf = TfidfVectorizer()
vector = tfidf.fit_transform(text)
X = vector.toarray()

# %%
y = train['sentiment']

# %% [markdown]
# #### As the target column was imbalanced, we decided to use stratify

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0,stratify=y)

# %% [markdown]
# #### Basic Vanilla Model

# %%
log_reg = LogisticRegression(max_iter=200,n_jobs=2)
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=2, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = log_reg.predict(X_test)

# %%
f1 = f1_score(y_test,y_pred,average="weighted")
f1
# Out:
# 0.6543150390114427

# %% [markdown]
# #### Test Data Processing

# %%
test = pd.read_csv("data/test.csv").set_index("tweet_id")

# %%
test.head(10)
# Out:
#                                                                                                                                                 tweet
# tweet_id
# 7506       Audience Q: What prototyping tools do you use? Sketchbooks/sharpie pens, photoshop, Balsamic, Google docs, Axsure, etc. #myprototype #sxsw
# 7992                     At SXSW? Send Your Best Photos &amp; Videos to... {link} #citizen_journalism #cnn #ireport #photography #sxsw #Cyber #iPhone
# 247                                      @mention  and here's a pic of you winning your ipad! #unsix #sxsw cc @mention @mention  {link} (cont) {link}
# 7688                    Google Marissa Mayer: mobile phone as a cursor of physical location - new version of map fast and more real life like   #sxsw
# 3294                                                                                                  #SXSW Google maps is even cooler than I thought
# 6125                                                                          RT @mention In front of @mention popup store at #SXSW last night {link}
# 6131                                     RT @mention In my next life I'm coming back as an iPad 2. Women can't keep their hands off this thing. #SXSW
# 4134                                                                                            Google celebrating Pi Day in style at #SXSW -  {link}
# 8206                                                                           Hmmm is it a bit weird that #sxsw is not tending but Google Circle is?
# 8552      @mention to launch 'Circles' later today at #SXSW?? gotta love #SXSW - one platform for everything from Independent film to Innovative Tech

# %% [markdown]
# #### Remove @mention
# #### Remove {link}
# #### Remove html tags
# As there are multiple html tags in the tweet column

# %% [raw]
# Eg: &quot;,&amp;

# %%
pattern = "@[\w]*"
test['tweet'] = test['tweet'].apply(lambda x:remov_pattern(pattern,str(x)))

pattern = "{[\w }]*"
test['tweet'] = test['tweet'].apply(lambda x:remov_pattern(pattern,x))

test['tweet'] = test['tweet'].apply(lambda x:html.unescape(x))

#pattern = "&[\w;]*"
#train['tweet'] = train['tweet'].apply(lambda x:remov_pattern(pattern,x))

# %%
def treat_slangs(row,slang_dict):
    words = row.split()
    treated_row = []
    reformed = []
    for word in words:
        if word.upper() in slang_dict.keys():
            new_word = word.replace(word,slang_dict[word.upper()])
            treated_row.append(new_word)
        else:
            treated_row.append(word)
    reformed = " ".join(treated_row)
    return reformed
test['tweet'] = test['tweet'].apply(lambda x:treat_slangs(x,slangs_dict))

# %%
def apostrophe_correction(row): 
    words = row.split()
    cleaned_row = []
    for word in words:
        for apostrophe in apostrophes:
            if apostrophe in word:
                word = word.replace(apostrophe, apostrophes[apostrophe]) 
        cleaned_row.append(word)
    reformed = " ".join(cleaned_row)
    return reformed
test['tweet']=test.tweet.apply(apostrophe_correction)

# %%
tb_polarity = []
tb_subjectivity = []
for row in test["tweet"]:
    temp = TextBlob(row)
    tb_polarity.append(temp.sentiment[0])
    tb_subjectivity.append(temp.sentiment[1])
test["tb_polarity"] = tb_polarity
test["tb_subjectivity"] = tb_subjectivity

# %%
#IGNORE..............

analyser = SentimentIntensityAnalyzer()
vs_polarity = []
for row in test["tweet"]:
    temp = analyser.polarity_scores(row)['compound']
    vs_polarity.append(temp)
test["vs_polarity"] = vs_polarity

# %%
pattern = "[^a-zA-Z\s#]" 
test['tweet'] = test['tweet'].apply(lambda x:remov_pattern(pattern,x))

# %%
test.head()
# Out:
#                                                                                                                       tweet  \
# tweet_id
# 7506      [audience, q, prototyping, tools, use, sketchbooks/sharpie, pens, photoshop, balsamic, google, docs, axsure, etc]
# 7992                                                                           [sxsw, send, best, photos, amp, videos, ...]
# 247                                                                                          [pic, winning, ipad, cc, cont]
# 7688         [google, marissa, mayer, mobile, phone, cursor, physical, location, new, version, map, fast, real, life, like]
# 3294                                                                                  [google, maps, even, cooler, thought]
#
#                                                               hashtags
# tweet_id
# 7506                                                  myprototype sxsw
# 7992      citizen_journalism cnn ireport photography sxsw cyber iphone
# 247                                                         unsix sxsw
# 7688                                                              sxsw
# 3294                                                              sxsw

# %%
test['hashtags'] = test['tweet'].apply(lambda x:','.join(re.findall("#[\w]*",x)))
test['hashtags'] = test['hashtags'].apply(lambda x:re.sub("[#]*","",x))
test['hashtags'] = test['hashtags'].apply(lambda x:x.lower())

# %%
test['hashtags'] = test['hashtags'].apply(lambda x: re.sub(","," ",x))

# %%
test['tweet'] = test['tweet'].apply(lambda x:re.sub("#[\w]*",'',x))

# %%
test['tweet'] = test['tweet'].apply(lambda x:x.lower())

# %%
test['tweet'] = test['tweet'].apply(lambda x:re.sub(r"\brt","",x))

# %%
test.head(10)
# Out:
#                                                                                                                               tweet  \
# tweet_id
# 7506      audience q: what prototyping tools do you use? sketchbooks/sharpie pens, photoshop, balsamic, google docs, axsure, etc.
# 7992                                                                       at sxsw? send your best photos &amp; videos to...
# 247                                                                         and here is a pic of you winning your ipad!   cc (cont)
# 7688         google marissa mayer: mobile phone as a cursor of physical location - new version of map fast and more real life like
# 3294                                                                                      google maps is even cooler than i thought
# 6125                                                                                         in front of popup store at  last night
# 6131                                   in my next life i'm coming back as an ipad 2. women cannot keep their hands off this thing.
# 4134                                                                                       google celebrating pi day in style at  -
# 8206                                                              hmmm is it a bit weird that  is not tending but google circle is?
# 8552       to launch 'circles' later today at ?? gotta love  - one platform for everything from independent film to innovative tech
#
#                                                               hashtags
# tweet_id
# 7506                                                  myprototype sxsw
# 7992      citizen_journalism cnn ireport photography sxsw cyber iphone
# 247                                                         unsix sxsw
# 7688                                                              sxsw
# 3294                                                              sxsw
# 6125                                                              sxsw
# 6131                                                              sxsw
# 4134                                                              sxsw
# 8206                                                              sxsw
# 8552                                                         sxsw sxsw

# %%
stop_words = list(set(stopwords.words('english')))+list(punctuation)
test['tweet'] = test['tweet'].apply(lambda x:word_tokenize(x))
test['tweet'] = test['tweet'].apply(lambda x:[word for word in x if word not in stop_words])

# %%
test['tweet'] = test['tweet'].apply(lambda x:[lemma.lemmatize(i) for i in x])

# %%
test['tweet'] = test['tweet'].apply(lambda x:' '.join(x))

# %%
test.head()
# Out:
#                                                                                                     tweet  \
# tweet_id
# 7506      audience q prototyping tool use sketchbookssharpie pen photoshop balsamic google doc axsure etc
# 7992                                                                           sxsw send best photo video
# 247                                                                          picture winning ipad cc cont
# 7688       google marissa mayer mobile phone cursor physical location new version map fast real life like
# 3294                                                                       google map even cooler thought
#
#           tb_polarity  tb_subjectivity  \
# tweet_id
# 7506         0.000000         0.000000
# 7992         1.000000         0.300000
# 247          0.625000         0.750000
# 7688         0.207273         0.399481
# 3294         0.000000         0.000000
#
#                                                              hashtags
# tweet_id
# 7506                                                 myprototype sxsw
# 7992      citizenjournalism cnn ireport photography sxsw cyber iphone
# 247                                                        unsix sxsw
# 7688                                                             sxsw
# 3294                                                             sxsw

# %%
#cv = CountVectorizer()
text = test['tweet']
vector = cv.transform(text)
X = vector.toarray()

# %%
tfidf = TfidfVectorizer()
vector = tfidf.transform(text)
X = vector.toarray()

# %%
y_pred = log_reg.predict(X)

# %%
y_pred
# Out:
# array([1, 1, 2, ..., 2, 1, 1], dtype=int64)

# %%
X.shape
# Out:
# (1819, 7081)

# %% [markdown]
# #### Exporting Cleaned Data

# %%
train.to_csv("treated_train.csv")
test.to_csv("treated_test.csv")

# %% [markdown]
# #### Submission File

# %%
sample_submission = pd.DataFrame(y_pred,test.index,columns=['sentiment'])

# %%
sample_submission
# Out:
#           sentiment
# tweet_id
# 7506              1
# 7992              1
# 247               2
# 7688              2
# 3294              2
# ...             ...
# 1550              2
# 1933              2
# 9052              2
# 4219              1
# 7210              1
#
# [1819 rows x 1 columns]

# %%
sample_submission.to_csv("sample_sub.csv")
